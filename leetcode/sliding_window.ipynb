# %% [markdown]
# # leet 643

# %%
nums = [1,12,-5,-6,50,3]
k = 4

def findMaxAverage():
    window_sum = sum(nums[:k])
    max_sum = window_sum

    for i in range(k, len(nums)):
        print(i, nums[i])
        window_sum += nums[i]
        window_sum -= nums[i-k]
        if window_sum > max_sum:
            max_sum = window_sum

    # return 
    max_sum/k
# Out:
# 4 50
# 5 3
# 12.75

# %%
def findMaxAverage():
    sub_sum = sum(nums[:k])
    max_sum = sub_sum

    for i in range(k, len(nums)):
        sub_sum += nums[i]
        sub_sum -= nums[k-i]
        if sub_sum > max_sum:
            max_sum = sub_sum
    
    return max_sum / k 

findMaxAverage()
# Out:
# 12.75
