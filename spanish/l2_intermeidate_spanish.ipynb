# %% [markdown]
# # level 2 intermeidate spanish

# %%
l2b = """  
id	español	ingles 	notas
1	el ejército	army	
2	el aviso	notice	
3	egoísta	selfish	
4	inolvidable	unforgettable	
5	la cancha	court	
6	vencer	to defeat	
7	faltar	to miss	
8	emocionante	exciting	
9	la juventud	youth	
10	la ciencia	science	
11	ansioso	anxious	
12	diseñar	to design	
13	encantado	delighted	
14	borrar	to delete	
15	prohibir	to prohibit	
16	la asignatura	subject	
17	orgulloso	proud	
18	estrecho	narrow	
19	denunciar	to report	
20	renunciar	to resign	
21	sonreír	to smile	
22	la paciencia	patience	
23	hacia	toward	
24	débil	weak	
25	la bandera	flag	
26	la respuesta	response	
27	el ciudadano	citizen	
28	favorito	favorite	
29	hacer cola	to get in line	
30	el suceso	event	
31	la calidad	quality	
32	aconsejar	to advise	
33	votar	to vote	
34	extranjero	foreign	
35	ambicioso	greedy	
36	enorme	enormous	
37	sudar	to sweat	
38	perjudicar	to be detrimental to	
39	aguantar	to put up with	
40	culpable	guilty	
41	próximo	next	
42	agotar	to exhaust	
43	útil	useful	
44	la risa	laughter	
45	anciano	elderly	
46	proponer	to propose	
47	la grasa	fat	
48	valorar	to value	
49	el hogar	home	
50	el empresario	businessman	
51	la carrera	race	
52	la huésped	guest	
53	reconocer	to recognize	
54	el diccionario	dictionary	
55	acordarse	to remember	
56	el nacimiento	birth	
57	rápido	fast	
58	respirar	breathe	
59	el servicio	service	
60	descargar	to download	
61	el calor	heat	
62	el patrimonio	heritage	
63	levantar	to lift	
64	pelearse	to fight	
65	el género	gender	
66	soleado	sunny	
67	el robo	robbery	
68	engordar	to gain weight	
69	familia	family	
70	pelear	to fight	
71	la muerte	death	
72	mentir	to lie	
73	salvaje	wild	
74	el perfil	profile	
75	la majoria	majority	
76	el sueño	dream	
77	la temporada	season	
78	la contabilidad	accounting	
79	el bienestar	well-being	
80	el técnico	technician	
81	componer	to make up	
82	producir	to produce	
83	el guion	script	
84	leal	loyal	
85	levantar pesas	to lift weight	
86	sugerir	to suggest	
87	la ruta	route	
88	el síntoma	symptom	
89	la marca	mark	
90	el relato	story	
91	el ensayo	essay	
92	invertir	to invest	
93	activo	active	
94	el discurso	speech	
95	la alegría	joy	
96	el almacén	store	
97	el folleto	brochure	
98	enojarse	to get angry	
99	el impuesto	tax	
100	tener prisa	to be in a hurry	
101	oscuro	dark	
102	el vecino	neighbor	
103	la medida	measurement	
104	aburrirse	to be bored	
105	adónde	where	
106	graduarse	to graduate	
107	sincero	sincere	
108	siguiente	next	
109	la época	period	
110	sensible	sensitive	
111	el origen	origin	
112	el compromiso	commitment	
113	entrevistar	to interview	
114	apretado	tight	
115	disminuir	to decrease	
116	la pesadilla	nightmare	
117	normalmente	normally	
118	la serie	series	
119	el cuento	story	
120	cariñoso	affectionate	
121	esconder	to hide	
122	frecuentemente	frequently 	
123	sabio	wise	
124	el consejero	counselor	
125	la competencia	competition	
126	el aire	air	
127	atraer	to attract	
128	el descuento	discount	
129	apreciar	to appreciate	
130	comprensivo	understanding	
131	el pariente	relative	
132	alegrarse	to be happy	
133	el informe	report	
134	la administración de empresas	business administration	
135	obedecer	to obey	
136	la soledad	loneliness	
137	agradable	nice	
138	el movimiento	movement	
139	sembrar	to plant	
140	derramar	to spill	
141	el argumento	argument	
142	el comercio	trade	
143	tener hambre	to be hungry	
144	la química	chemistry	
145	la ventanilla	window	
146	interpretar	to interpret	
147	la Tierra	Earth	
148	el alquiler	rent	
149	prevenir	to prevent	
150	duro	hard	
151	el compañero de clase	classmate	
152	el racismo	racism	
153	la razón	reason	
154	el accidente	accident	
155	el aniversario	anniversary	
156	doblar	to turn	
157	permitir	to allow	
158	ancho	wide	
159	profesional	professional	
160	aburrir	to bore	
161	mantener	to hold	
162	el peso	weight	
163	la edad	age	
164	revisar	to review	
165	pronto	soon	
166	el tema	subject	
167	preocupado	worried	
168	la ley	law	
169	popular	popular	
170	por fin	finally	
171	la talla	size	
172	tener miedo	to be afraid	
173	capaz	able	
174	temer	to fear	
175	maravilloso	wonderful	
176	promover	to promote	
177	abrazar	to hug	
178	bello	beautiful	
179	contratar	to hire	
180	enamorado	in love	
181	el presupuesto	budget	
182	conversar	to maintain	
183	la esperanza	hope	
184	coger	to take	
185	jamás	never	
186	suponer	to suppose	
187	el apoyo	support	
188	desaparecer	disappear	
189	a tiempo	on time	
190	la confianza	trust	
191	el conocimiento	knowledge	
192	el espacio	space	
193	apoyar	to support	
194	pescar	to fish	
195	jurar	to swear	
196	la obra	work	
197	el edificio	building	
198	la huelga	strike	
199	el cielo	sky	
200	convertirse en	to turn into	
201	de acuerdo	okay	
202	negar	to deny	
203	fresco	fresh	
204	la lucha	fight	
205	precioso	precious	
206	entrenarse	to train	
207	normal	normal	
208	el proyecto	project	
209	la costa	coast	
210	la capital	capital	
211	quizá	maybe	
212	estudioso	studious	
213	el respeto	respect	
214	formal	formal	
215	confiar	to confide	
216	contrario	opposite	
217	dentro de	inside	
218	el hambre	hunger	
219	el negocio	business	
220	enfermo	sick	
221	el material	material	
222	muy bien	very good	
223	el curso	course	
224	el error	mistake	
225	anunciar	to announce	
226	reservar	to reserve	
227	aparecer	to appear	
228	charlar	to chat	
229	el asiento	seat	
230	vivo	alive	
231	el pago	payment	
232	menor	young	
233	el periodismo	journalism	
234	la actitud	attitude	
235	batir	to beat	
236	emocionado	excited	
237	la regla	rule	
238	la herramienta	tool	
239	lejos de	far from	
240	las redes sociales	social media	
241	eficaz	effective	
242	suficiente	enough	
243	el acontecimiento	event	
244	asegurar	to assure	
245	el éxito	success	
246	responder	to answer	
247	el taller	workshop	
248	la factura	invoice	
249	mezclar	to mix	
250	atrevido	daring	
251	desafortunadamente	unfortunately	
252	enfermarse	to get sick	
253	fiel	faithful	
254	diario	daily	
255	celoso	jealous	
256	la amenaza	threat	
257	igualmente	likewise	
258	el ambiente	environment	
259	ausente	absent	
260	el juguete	toy	
261	ligero	light	
262	la leyenda	legend	
263	dudar	to doubt	
264	la señorita	miss	
265	el recuerdo	memory	
266	conversar	to talk	
267	el comportamiento	behavior	
268	reemplazar	to replace	
269	rápidamente	quickly	
270	el fuego	fire	
271	el pasado	past	
272	el juez	judge	
273	generoso	generous	
274	cómico	funny	
275	el despertador	alarm clock	
276	el castigo	punishment	
277	la receta	prescription	
278	exigir	to demand	
279	disponible	available	
280	el significado	meaning	
281	tratar de	to try	
282	la nacionalidad	nationality	
283	mudarse	to move	
284	enfrentar	to confront	
285	robar 	to steal	
286	el compañero	companion	
287	soltero	single	
288	apenas	barely	
289	la pena	shame	
290	estupendo	great	
291	claro	clear	
292	despedir	to fire	
293	el camino	road	
294	el grado	degree	
295	genial	great	can also mean brilliant(like in an intelligent way), or funny/witty
296	ir a 	to go to	
297	muchas gracias	thank you very much	
298	fascinar	to fascinate	
299	respetar	to respect	
300	quitarse	to take off	
301	la paz	peace	
302	el hecho	fact	
303	interesar	to interest	
304	cobrar	to charge for	
305	igual	equal	
306	buenas tardes	good afternoon	
307	vago	lazy	
308	la clave	key	
309	hermoso	beautiful	
310	probarse	to try on	
311	por supuesto	of course	
312	el oso	bear	
313	la sangre	blood	
314	utilizar	to use	
315	flexible	flexible	
316	el enlace	link	
317	medir	to measure	
318	elegir	to choose	
319	relajarse	to relax	
320	recorrer	to travel around	
321	crecer	to grow	
322	alquilar	to rent	
323	aprovechar	to take advantage of	
324	transmitir	to transmit	
325	aumentar	to increase	
326	cazar	to hunt	
327	colocar	to place	
328	importar	to matter	
329	presentar	to introduce	
330	saltar	to jump	
331	soler	to use to	
332	jubilarse	to retire	
333	amenazar	to threaten	
334	matar	to kill	
335	la vez	time	
336	el puente	bridge	
337	regalar	to give	
338	el mensaje	message	
339	terrible	terrible	
340	el mundo	world	
341	el sol	sun	
342	saludar	to greet	
343	soñar	to dream	
344	ocupado	busy	
345	despedirse	to say goodbye to	
346	tener que	to have to	
347	romperse	to break	
348	destruir	to destroy	
349	lleno	full	
350	preocuparse	to worry	
351	buenas noches	good evening	
352	volar	to fly	
353	horrible	horrible	
354	último	last	
355	construir	to build	
356	encender	to turn on	
357	crear	to create	
358	gritar	to shout	
359	describir	to describe	
360	llorar	to cry	na

"""

# %%
l2 = """  

id	español	ingles 	other_common_meanings
1	el ejército	army	
2	el aviso	notice	
3	egoísta	selfish	
4	inolvidable	unforgettable	
5	la cancha	court	
6	vencer	to defeat	
7	faltar	to miss	
8	emocionante	exciting	
9	la juventud	youth	
10	la ciencia	science	
11	ansioso	anxious	
12	diseñar	to design	
13	encantado	delighted	
14	borrar	to delete	
15	prohibir	to prohibit	
16	la asignatura	subject	
17	orgulloso	proud	
18	estrecho	narrow	
19	denunciar	to report	
20	renunciar	to resign	
21	sonreír	to smile	
22	la paciencia	patience	
23	hacia	toward	
24	débil	weak	
25	la bandera	flag	
26	la respuesta	response	
27	el ciudadano	citizen	
28	favorito	favorite	
29	hacer cola	to get in line	
30	el suceso	event	
31	la calidad	quality	
32	aconsejar	to advise	
33	votar	to vote	
34	extranjero	foreign	
35	ambicioso	greedy	
36	enorme	enormous	
37	sudar	to sweat	
38	perjudicar	to be detrimental to	
39	aguantar	to put up with	
40	culpable	guilty	
41	próximo	next	
42	agotar	to exhaust	
43	útil	useful	
44	la risa	laughter	
45	anciano	elderly	
46	proponer	to propose	
47	la grasa	fat	
48	valorar	to value	
49	el hogar	home	
50	el empresario	businessman	
51	la carrera	race	
52	la huésped	guest	
472	la estatua	statue	
473	el desastre	disaster	similar spelling & pronounciation but kind of diff
474	el divorcio	divorce	
475	el aumento	increase	
476	el laboratorio	laboratory	"-orio" to "-ory" pattern? 
477	quitar la mesa	to clear the table	
478	el campeón	champion	
479	tener éxito	to be successful	
480	llevarse bien	to get along	
481	el sitio web	website	
482	la responsabilidad	responsibility	
483	por último	finally	
484	hablador	talkative	
485	el punto de vista	point of view	
486	el archivo	file	
487	llegar tarde	to be late	
488	el reportaje	report	
489	el juego de mesa	board game	
490	el entrevistador	interviewer	
491	la estrategia	strategy	
492	la deforestación	deforestation	
493	lujoso	luxurious	
494	la infancia	childhood	
495	la crítica	criticism	
496	el invitado	guest	
497	disfrutar de	to enjoy	
498	el consumo	consumption	
499	escalar montañas	to climb mountains	
500	el recurso natural	natural resource	
501	realista	realistic 	
502	estar a dieta	to be on a diet	
503	ir de vacaciones	to go on vacation	
504	hacer un viaje	to take a trip	
505	pasarlo mal	to have a bad time	
506	sostenible	sustainable	
507	el reportero	reporter	
508	ganarse la vida	to earn a living	
509	la manifestación	demonstration	
510	el usuario	user	
511	la sanidad	health	
512	el desempleo	unemployment	
513	el equilibrio	balance	
514	el edificio de apartamentos	apartment building	
515	llevarse mal	to get along badly	
516	el beneficio	profit	
517	la ecologista	environmentalist	
518	la autoestima	self-esteem	
519	nutritivo	nutritious	
520	la diversión	entertainment	
521	apasionado	passionate	
522	comentar	to discuss	
523	el medicamento	medicine	
524	el cambio climático	climate change	
525	el agricultor	farmer	
526	el funcionario	civil servant	
527	equilibrado	balanced	
528	el enfado	anger	
529	el petróleo	oil	
530	la publicidad	advertising	
531	la entrega	delivery	
532	la ciencia ficción	science fiction	
533	la computación	computer science	
534	el rescate	rescue	
535	el envase	container	
536	la informática	computing	
537	el requisito	requirement	
538	el campamento	camp	
539	el consumidor	consumer	
540	elaborar	to make	
541	la aspirante	applicant	
542	el ascenso	promotion	
543	el descubrimiento	discovery	
544	el retraso	delay	
545	la indígena	native	
546	el árbitro	referee	
547	el diseñador	designer	
548	el préstamo	loan	
549	desigualdad	inequality	
550	el ayuntamiento	city council	
551	pedir prestado	to borrow	transitive verb phrase
552	el malentendido	misunderstanding	
553	empatar	to tie	
554	presumido	conceited	
555	la inundación	flood	
556	la sabiduría	wisdom	
557	el calentamiento global	global warming	
558	adelgazar	to lose weight	
559	aplaudir	to applaud	
560	el aficionado	fan	
561	la sequía	drought	
562	el título	title	
563	el océano	ocean	
564	adolescencia	adolescence	
565	grave	serious	

"""

# %%
import pandas as pd
from io import StringIO
import textwrap

l2_df = pd.read_csv(
    StringIO(textwrap.dedent(l2).strip()),
    sep="\t",
    na_values=["na"],
)

l2_df.head()
# Out:
#    id      español        ingles  other_common_meanings
# 0   1  el ejército           army                   NaN
# 1   2     el aviso         notice                   NaN
# 2   3      egoísta        selfish                   NaN
# 3   4  inolvidable  unforgettable                   NaN
# 4   5    la cancha          court                   NaN

# %%
len(l2_df)
# Out:
# 565

# %%
l2_df.to_csv('intermedio_espanol.csv', index=False)

# %% [markdown]
# # prompt 1:
#
# I am learning Spanish and I am primarily using spanishdictionary.com to learn it. I made a list of words I am studying from that it.
#
# given the list of spanish words and their english meaning
# - add a column for part of speech e.g. noun, verb
# - if its a verb add another coliumn that lists its' verb forms e.g. intrasitive, prominal, recepricol, reflexive, transitive
# - put a few additional common meanings
#
#
# Then create a 2nd table / csv that creates sentencs using randomly selected words in the list.
# Combine the various verbs and nouns in the list to create sentences.
# For verbs use verb conjucations in present, preterite, imperfect, conditional, future tenses of subjects "I", "you", "he/she", "they", "we".
# Use creative but common political scenarios when making sentences. Pretend you are campaigning for California Governor and you are talking about / making a speech about common issues, the various stances on those issues, solutions and motivation.
# Only use the indicative form because that is what I am trying to learn right now.
# You can use other words outside of this list needed to create the sentences (e.g. prepositions and additional adverbs, adjectives, nouns, verbs anything you need to create sentences but primarily combine the words in the list as much as possible but you are not limited to just the list)
# The 2nd table / csv will have the Spanish sentence then the English translation. I am going to use read the Spanish sentence then attempt to translate it to English, then I am going to read the English sentence then attempt to translate it to Spanish. I am doing to to learn and practice.
# I am going to build a personal web app tool to use for this.
# Please add your own ideas to make this all even better.

# %% [markdown]
# # prompt 2:
#
# I am learning Spanish using spanishdictionary.com as my main resource, and I have compiled a list of Spanish words along with their English meanings.
#
# Your tasks are as follows:
#
# 1. **Enrich the vocabulary table**
#    - Given the list of Spanish words and their English meanings:
#      - Add a column for **part of speech** (e.g., noun, verb, adjective, adverb).
#      - If the word is a **verb**, add an additional column describing its **verb type(s)** (e.g., intransitive, pronominal, reciprocal, reflexive, transitive).
#      - Add a few **additional common meanings or nuances** (based on dictionary usage or idiomatic expressions).
#
# 2. **Generate a practice dataset**
#    - Create a **second table or CSV** that contains **Spanish practice sentences** generated using randomly selected words from the list.
#    - Combine verbs and nouns from the list to form natural, grammatically correct sentences.
#    - Use **only the indicative mood**, and include **verb conjugations** in the following tenses:
#      - Present
#      - Preterite
#      - Imperfect
#      - Conditional
#      - Future
#    - Cover all main subjects: *yo, tú, él/ella, nosotros, ellos/ellas*.
#    - The sentences should relate to **common political themes**, as if I were **campaigning for California Governor** — addressing issues, policies, solutions, and motivational statements.
#    - You may use **additional words** (e.g., prepositions, adverbs, adjectives, or helper verbs) as needed to make sentences natural and meaningful, but focus primarily on incorporating words from the provided list.
#
# 3. **Sentence translation table**
#    - The second CSV/table should have two columns:
#      - **Spanish Sentence**
#      - **English Translation**
#    - I will use these pairs for bilingual translation practice — reading the Spanish and translating to English, then vice versa.
#
# 4. **Enhancements**
#    - Feel free to add your own ideas or improvements to make this learning tool more effective and engaging. For example:
#      - Include IPA pronunciation.
#      - Add sentence-level grammar notes.
#      - Group sentences by tense or topic.
#
# The final output should be two clean, well-structured CSV tables ready for import into a web app for interactive Spanish learning.

# %% [markdown]
# # prompt 3:
#
# You are helping me enrich and analyze a Spanish vocabulary list that I uploaded as a CSV. The file contains two columns:
#
# * `spanish` — the Spanish word or expression
# * `english` — its English meaning
#
# Your tasks are as follows:
#
# ---
#
# ### 1. Enrich the vocabulary data
#
# For each row in the uploaded list:
#
# * **Add a part of speech (POS)** such as noun, verb, adjective, adverb, pronoun, preposition, conjunction, or interjection.
# * **If it’s a verb**, also add its **verb type(s)** (e.g., transitive, intransitive, pronominal, reciprocal, reflexive).
# * **Add the base or root form** (lemma). For example:
#
#   * “rápidamente” → “rápido”
#   * “comunicación” → “comunicarse”
#   * “rastreador” → “rastrear”
# * **Identify morphological family patterns** such as:
#
#   * ADJ→ADV (rápido → rápidamente)
#   * V→N (-ar → -ador / -ción)
#   * N→ADJ (-ario / -oso / -al / -ico)
# * **Add related words from the same morphological family** if they exist in the dataset.
# * **Add a few additional common meanings** (e.g., idiomatic or secondary uses).
# * **Optionally add a short IPA pronunciation** (blank if unknown).
# * **Add a “notes” column** if relevant grammar or usage notes exist.
#
# ---
#
# ### 2. Calculate similarity between Spanish and English
#
# Add a `similarity_score` between 0 and 1 based on how visually and phonetically similar the two words are.
# You may approximate this by considering:
#
# * Shared root or cognate patterns (e.g., *doctor/doctor*, *nación/nation*).
# * Levenshtein or spelling distance.
# * Common suffix transformations:
#
#   * -ción ↔ -tion
#   * -dad ↔ -ty
#   * -mente ↔ -ly
#   * -ario ↔ -ary
#   * -oso ↔ -ous
# * Also include a short explanation column (e.g., “same Latin root”, “suffix match”, “different origin”).
#
# ---
#
# ### 3. Generate practice sentences
#
# Create a second table (or CSV) with these columns:
#
# * `id`
# * `topic` (choose from economy, education, healthcare, environment, immigration, housing, tech_jobs, public_safety, water_infrastructure)
# * `tense` (present, preterite, imperfect, conditional, future)
# * `subject` (yo, tú, él/ella, nosotros, ellos/ellas)
# * `spanish_sentence`
# * `english_translation`
# * `target_words` (words from the list used)
# * `grammar_notes` (brief note about the tense or structure)
#
# **Sentence rules:**
#
# * Only use **indicative mood**.
# * Sentences should sound **natural and political**, as if I were **campaigning for California Governor**, addressing issues, policies, or motivation.
# * Use 8–12 words.
# * Prioritize words from my list, but add connecting words as needed.
# * Include at least one example for each tense and subject.
#
# ---
#
# ### 4. Output format
#
# * First, show me a **sample of 10 enriched vocabulary rows** in a markdown table.
# * Then, show me **10 sample practice sentences** in a separate markdown table.
# * Confirm whether you want to export to CSV, and if I say yes, output downloadable CSVs:
#
#   * `vocab_enriched.csv`
#   * `sentences.csv`
#
# ---
#
# ### 5. Optional enhancements (if time/space allows)
#
# * Group sentences by topic or tense.
# * Add simple grammar or cultural notes.
# * Suggest additional derivations or cognate pairs not in the original list.

# %% [markdown]
# # codex prompt
#
#
# PROMPT:
#
# Write a single Python script (VS Code Jupyter cell) that:
#
# 1. Reads vocab_input.csv with columns: spanish, english (UTF-8, comma, header).
# 2. Produces vocab_enriched.csv and sentences.csv.
# 3. Adds morphology, cognate/similarity scoring, and keeps all prior constraints.
#
# OUTPUT A: vocab_enriched.csv (snake_case)
#
# * spanish (str)
# * english (str)
# * lemma (base form; verbs → infinitive; adverbs in -mente → base adjective; nouns/adjs strip common derivational suffixes conservatively)
# * pos (noun|verb|adjective|adverb|pronoun|preposition|conjunction|interjection|determiner|phrase)
# * verb_types (pipe: transitive|intransitive|pronominal|reciprocal|reflexive; empty if non-verb)
# * additional_meanings (semicolon list)
# * ipa (blank)
# * notes (optional)
# * morph_family (pipe-delimited related forms discovered heuristically from the list, e.g., rápido|rápidamente)
# * morph_patterns (pipe-delimited tags applied, e.g., ADJ→ADV_mente, V→N_ador, N→ADJ_ario)
# * similarity_score (0–1 float; higher = more similar)
# * similarity_components (json string of sub-scores)
#
# OUTPUT B: sentences.csv
#
# * id (int)
# * topic (economy|public_safety|education|housing|water_infrastructure|immigration|healthcare|environment|tech_jobs)
# * tense (present|preterite|imperfect|conditional|future)  # indicative only
# * subject (yo|tú|él/ella|nosotros|ellos/ellas)
# * spanish_sentence
# * english_translation
# * target_words (pipe-delimited)
# * grammar_notes (≤1 short note)
#
# IMPLEMENTATION DETAILS
#
# * Use only stdlib + pandas. No internet.
# * Normalize to NFC; lower-case working copies; preserve original “spanish”.
# * POS inference: verbs end -ar/-er/-ir; words ending -mente → adverb; -ción/-sión → noun; -dad/-tad/-edad/-itud/-umbre → noun; -ista/-ero/-or/-ario → noun/adj; -oso/-al/-ico/-ario → adj. Default “noun” if unknown.
# * Lemma rules:
#
#   * Verbs: if endswith -ar/-er/-ir → itself; if pronominal (se) → strip “se”.
#   * Adverbs: Xmente → base adj X (handle rápida→rápidamente via dropping final -a/-e if present).
#   * N/Adj derivational stripping (conservative): remove one suffix if present in
#     [mente, ción, sión, dad, tad, edad, idad, itud, umbre, ura, eza, anza, encia, ancia, ario, ista, ero, ador, ición]
#     then tidy orthography minimally (e.g., ción→ción base often ends in -ar/-er/-ir guess only if plausible; else keep stripped form).
# * Morph family: within the given list, link entries sharing stripped stems (after accent-insensitive compare) and known pattern pairs:
#   ADJ↔ADV(mente), V↔N(ador/edor/idor), V↔N(ción from verbs), N↔ADJ(ario/oso/al/ico), V↔PRONOMINAL(se).
# * Verb types: default transitive/intransitive heuristics; mark pronominal if “se” form exists.
# * Similarity scoring (0–1):
#
#   * s1 = 1 - normalized Levenshtein(spanish_ascii, english_ascii)
#   * s2 = consonant-skeleton Jaccard overlap
#   * s3 = suffix cognate boost (-ción↔-tion, -dad↔-ty, -mente↔-ly, -ista↔-ist, -ario↔-ary, -oso↔-ous). s3 ∈ {0, .1, .2}
#   * s4 = accent-insensitive prefix overlap ratio (first 3–4 chars)
#   * similarity_score = clip(0.1*s1 + 0.2*s2 + 0.6*s4 + s3, 0, 1)
#     Store {"s1":..,"s2":..,"s3":..,"s4":..,"rule":"…"} in similarity_components.
# * Conjugation helper: regular verbs only; for irregulars, fall back to infinitive with note.
# * Sentences: 60 by default (n_sentences), seed=42, length 8–12 words, indicative only, cover all subjects and tenses at least once. Prioritize list words; add glue words as needed; avoid named individuals.
# * Save both CSVs; print head(10) previews.
#
# DELIVERABLE
# Produce executable code with functions:
#
# * infer_pos(), infer_lemma(), apply_morph_patterns(), build_morph_family(df)
# * similarity_score(es, en) → (score, components)
# * conjugate(lemma, tense, subject)
# * generate_sentences(df, n_sentences=60)
#   Then run main() to read, enrich, generate, save, and preview.

# %% [markdown]
# # Example Sentences

# %%
sentences = """ 

# indirect + direct object pronouns example
Le dije a Ana la verdad. Le dije la verdad. Se lo dije. = I told Ana the truth. I told her the truth. I told her it. 

"""

# %% [markdown]
# # Additional Verbs

# %%
# verbs 2
v2 = """  

destaparse
reponerse
disgustarse de
alegrarse de
distraerse
subirse
enloquecerse


"""
